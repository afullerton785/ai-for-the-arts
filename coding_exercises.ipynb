# %% [markdown]
# # Hello, World!
#
# The following code was created as my first attempt at programming in this course. It is meant to help me understand how to write and run code in GitHub Codespaces.

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# # Basic Programming Concepts Notebook
#
# I have very little experience with coding so I imagine most if not all of these exercises will be new to me. As I progress I want to:
# - Gain more confidence in GitHub both in the repositories and in the codespaces.
# - Understand how the code I input works and why I need to type specific things.

# %% [markdown]
# # Printing
# Copilot Prompt:
# Could you suggest a python code for ‘Hello, world!’ to demonstrate the concept of printing to a
# complete beginner in programming? Please explain the code step-by-step highlighting any key aspects.
# Outcomes:
# I gained a better understanding of how the print command works and what the key concepts are.

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %% [markdown]
# # Variable Prompt in CoPilot

# %% [markdown]
# ### Initial Prompt
# "Could you suggest a modification of the Python code for “Hello, world!” to demonstrate the concept of variables to a complete beginner in programming? Please explain the code step-by-step highlighting any key aspects."
#
# ### Prompt Suggestion
# message = "Hello, world!"
#
# print(message)
#
# 📝 Step-by-Step Explanation:
#
# message = "Hello, world!"
#
# This line creates a variable named message.
# A variable is like a container that stores data — in this case, a string of text.
# The = sign is called the assignment operator. It assigns the value "Hello, world!" to the variable message.
# Now, whenever you use message, Python will treat it as "Hello, world!".
#
#
#
# print(message)
#
# This tells Python to display the value stored in the variable message.
# Instead of printing the string directly, we’re printing the contents of the variable.

# %%
message = "Hello, world!"
print(message)
# Out:
# Hello, world!

# %% [markdown]
# # Function Prompt in CoPilot
#
# ### Initial prompt
#
# "Could you suggest a modification of the Python code for “Hello, world!” to demonstrate the concept of functions to a complete beginner in programming? Please explain the code step-by-step highlighting any key aspects."
#
# ### Prompt Suggestion
#
# continue at home
